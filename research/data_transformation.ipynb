# %%
import os

# %%
# %pwd
# Out:
# 'd:\\DS_Project\\data_science_project\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'd:\\DS_Project\\data_science_project'

# %%
import pandas as pd
data = pd.read_csv("artifacts/data_ingestion/data.csv", sep = ";")

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
from dataclasses import dataclass
from pathlib import Path
@dataclass
class DataTransformationConfig:
    root_dir: Path
    data_path: Path

# %%
from src.datascience.constants import *
from src.datascience.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(self,
                config_filepath = CONFIG_FILE_PATH,
                params_filepath = PARAMS_FILE_PATH,
                schema_filepath = SCHEMA_FILE_PATH
                ):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])    # Create artifacts folder

    def get_data_transformation_config(self) -> DataTransformationConfig:
        config = self.config.data_transformation

        create_directories([config.root_dir])
        data_transformation_config = DataTransformationConfig(
            root_dir= config.root_dir,
            data_path = config.data_path
        )

        return data_transformation_config

# %%
import os
from src.datascience import logger
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
class DataTransformation:
    def __init__(self, config: DataTransformationConfig):
        self.config = config

    def train_test_splitting(self):
        data = pd.read_csv(self.config.data_path, sep = ";")

        train, test = train_test_split(data)

        train.to_csv(os.path.join(self.config.root_dir, "train.csv"), index = False)
        test.to_csv(os.path.join(self.config.root_dir, "test.csv"), index = False)

        logger.info("Splitted data into train and test")
        logger.info(train.shape)
        logger.info(test.shape)
                    
        print(train.shape)
        print(test.shape)

# %%
try:
    config = ConfigurationManager()
    data_transformation_config = config.get_data_transformation_config()
    data_transformation = DataTransformation(data_transformation_config)
    data_transformation.train_test_splitting()
except Exception as e:
    logger.exception(e)
    raise e
# Out:
# [2026-07-22 20:17:08,879: INFO: common: yaml file: config\config.yaml is loaded successfully]
# [2026-07-22 20:17:08,887: INFO: common: yaml file: params.yaml is loaded successfully]
# [2026-07-22 20:17:08,897: INFO: common: yaml file: schema.yaml is loaded successfully]
# [2026-07-22 20:17:08,904: INFO: common: Created directory at: artifacts]
# [2026-07-22 20:17:08,908: INFO: common: Created directory at: artifacts/data_transformation]
# [2026-07-22 20:17:09,097: INFO: 2601197503: Splitted data into train and test]
# [2026-07-22 20:17:09,102: INFO: 2601197503: (3673, 12)]
# [2026-07-22 20:17:09,104: INFO: 2601197503: (1225, 12)]
# (3673, 12)
# (1225, 12)
